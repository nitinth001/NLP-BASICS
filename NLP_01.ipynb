# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinth001/NLP-BASICS/blob/main/NLP_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus = """ HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.
I AM HOPING TO CONTINUE THIS JOURNEY FURTHUR WITH HIGE EXCITEMENT
"""
print(corpus)
# Out:
#  HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.
# I AM HOPING TO CONTINUE THIS JOURNEY FURTHUR WITH HIGE EXCITEMENT

# %%
import nltk
nltk.download('punkt')   # download tokenizer model (only first time)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
#tokenization:
# sentence tokenization:
corpus = """ HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.
I AM HOPING TO CONTINUE THIS JOURNEY! FURTHUR WITH HIGE EXCITEMENT
"""
print(corpus)
nltk.download('punkt_tab')   # Download the missing punkt_tab resource
from nltk.tokenize import sent_tokenize
doc = sent_tokenize(corpus)
# Out:
#  HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.
# I AM HOPING TO CONTINUE THIS JOURNEY! FURTHUR WITH HIGE EXCITEMENT
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
doc
# Out:
# [' HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.',
#  'I AM HOPING TO CONTINUE THIS JOURNEY!',
#  'FURTHUR WITH HIGE EXCITEMENT']

# %%
type(doc)
# Out:
# list

# %%
for sentence in doc:
  print(sentence)
# Out:
#  HELLO , MYSELF NITIN THAKUR, FOLLOWING NLP TUTORIALS.
# I AM HOPING TO CONTINUE THIS JOURNEY!
# FURTHUR WITH HIGE EXCITEMENT

# %%
# word tokenization: corpus -> word or sentence-> word
from nltk.tokenize import word_tokenize
a = word_tokenize(corpus)
a
# Out:
# ['HELLO',
#  ',',
#  'MYSELF',
#  'NITIN',
#  'THAKUR',
#  ',',
#  'FOLLOWING',
#  'NLP',
#  'TUTORIALS',
#  '.',
#  'I',
#  'AM',
#  'HOPING',
#  'TO',
#  'CONTINUE',
#  'THIS',
#  'JOURNEY',
#  '!',
#  'FURTHUR',
#  'WITH',
#  'HIGE',
#  'EXCITEMENT']

# %%
from nltk.tokenize import wordpunct_tokenize # more specific detailing to each word like inckuding appostrophy too..
b = word_tokenize(corpus)
b
# Out:
# ['HELLO',
#  ',',
#  'MYSELF',
#  'NITIN',
#  'THAKUR',
#  ',',
#  'FOLLOWING',
#  'NLP',
#  'TUTORIALS',
#  '.',
#  'I',
#  'AM',
#  'HOPING',
#  'TO',
#  'CONTINUE',
#  'THIS',
#  'JOURNEY',
#  '!',
#  'FURTHUR',
#  'WITH',
#  'HIGE',
#  'EXCITEMENT']

# %%
from nltk.tokenize import TreebankWordTokenizer
c = TreebankWordTokenizer()
c.tokenize(corpus)
# Out:
# ['HELLO',
#  ',',
#  'MYSELF',
#  'NITIN',
#  'THAKUR',
#  ',',
#  'FOLLOWING',
#  'NLP',
#  'TUTORIALS.',
#  'I',
#  'AM',
#  'HOPING',
#  'TO',
#  'CONTINUE',
#  'THIS',
#  'JOURNEY',
#  '!',
#  'FURTHUR',
#  'WITH',
#  'HIGE',
#  'EXCITEMENT']

# %% [markdown]
# | Tokenizer             | Output                                |
# | --------------------- | ------------------------------------- |
# | word_tokenize         | `['I','ca',"n't",'do','this','.']`    |
# | TreebankWordTokenizer | `['I','ca',"n't",'do','this','.']`    |
# | wordpunct_tokenize    | `['I','can',"'",'t','do','this','.']` |

# %% [markdown]
# Stemming (NLP) — Important Points (Short)
#
# Definition:
# Stemming is a process in NLP that reduces words to their root/base form by removing suffixes.

# %%
words = ["writing","writes","programming","programs","history",
         "finally","finalized","eating","eats","eaten"]

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
for word in words:
  print(word + "->" + ps.stem(word))
# Out:
# writing->write
# writes->write
# programming->program
# programs->program
# history->histori
# finally->final
# finalized->final
# eating->eat
# eats->eat
# eaten->eaten

# %%
ps.stem("congratulations")
# Out:
# 'congratul'

# %%
ps.stem("sitting")
# Out:
# 'sit'

# %%
#ways to improve porter stemming:
# REGEXP STEMMER:

# %% [markdown]
# RegexpStemmer (Regular Expression Stemmer) – NLTK
#
# RegexpStemmer is a stemmer in NLTK that removes suffixes using regular expressions (regex patterns).
#
# Unlike Porter or Lancaster stemmers, it does not use linguistic rules.
# Instead, it removes parts of words based on a pattern you define.

# %%
from nltk.stem import RegexpStemmer
reg_stemmer  = RegexpStemmer('ing$|s$|e$|able$', min=4)
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)
reg_stemmer.stem('ingeating') #ing$ means remove 'ing' only from last..
# Out:
# 'ingeat'

# %% [markdown]
# Snowball Stemmer (NLP)
#
# Snowball Stemmer is an improved version of the Porter Stemmer used for reducing words to their base/stem form.
#
# Snowball Stemmer removes suffixes from words using improved linguistic rules.
#
# Important Features:
#
# Improved Porter algorithm
#
# Supports many languages
#
# More consistent stemming
#
# Faster and cleaner implementation

# %%
from nltk.stem import SnowballStemmer
print(SnowballStemmer.languages)
# Out:
# ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %%
ss = SnowballStemmer('english')
ss.stem('eating')
# Out:
# 'eat'

# %%
ss = SnowballStemmer('english')
ss.stem('congratulations')
# Out:
# 'congratul'

# %%
ps.stem('fairly'), ps.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
ss.stem('fairly'), ss.stem('sportingly') #simply stemming adds more language words and slight improvement to porting not complete , which is solved by lemmitization only
# Out:
# ('fair', 'sport')

# %% [markdown]
# Lemmatization (NLP)
#
# Lemmatization is the process of converting a word to its base or dictionary form (called lemma) using vocabulary and grammar rules.

# %% [markdown]
# **Advantages:**
#
# Produces real dictionary words
#
# More accurate meaning
#
# Useful in chatbots and language understanding
#
# **Disadvantages:**
#
# Slower than stemming
#
# Requires dictionary (WordNet)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer.lemmatize('going',pos = 'n') # pos represents noun(n), verb(v), adverb(r), adjective(a) so based on word we have we select it
# Out:
# 'going'

# %%
lemmatizer.lemmatize('going',pos = 'v')
# Out:
# 'go'

# %%
words = ["writing","writes","programming","programs","history",
         "finally","finalized","eating","eats","eaten"]
for word in words:
  print(word + "->" + lemmatizer.lemmatize(word,pos='n'))
# Out:
# writing->writing
# writes->writes
# programming->programming
# programs->program
# history->history
# finally->finally
# finalized->finalized
# eating->eating
# eats->eats
# eaten->eaten

# %%
words = ["writing","writes","programming","programs","history",
         "finally","finalized","eating","eats","eaten"]
for word in words:
  print(word + "->" + lemmatizer.lemmatize(word,pos='v'))
# Out:
# writing->write
# writes->write
# programming->program
# programs->program
# history->history
# finally->finally
# finalized->finalize
# eating->eat
# eats->eat
# eaten->eat

# %%
lemmatizer.lemmatize('fairly',pos='v'), lemmatizer.lemmatize('sportingly',pos='v')
# Out:
# ('fairly', 'sportingly')

# %% [markdown]
# **APPLICATIONS OF LEMMATIZATION:**
# chatbots, QNA, text summarisation..
